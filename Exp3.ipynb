# %% [markdown]
# <a href="https://colab.research.google.com/github/anirxudh/Deep-Learning-Lab-Tutorial-KTU/blob/main/Exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXPERIMENT NO 3
# ## ANIRUDH S NAIR
# ### Feed Forward Network

# %% [markdown]
# # Library importing

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import models, layers, datasets

# %% [markdown]
# # Dataset loading and normalisation

# %%
(x_train, y_train),(x_test,y_test)=datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %% [markdown]
# # Model Building and Fitting

# %%
model=models.Sequential([
    layers.Flatten(input_shape=(32,32,3)),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128,activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
r= model.fit(x_train, y_train, epochs=120, validation_data=(x_test,y_test)) # increase epochs for better accuracy
# Out:
# Epoch 1/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7278 - loss: 0.7488 - val_accuracy: 0.4794 - val_loss: 2.1625
# Epoch 2/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7214 - loss: 0.7601 - val_accuracy: 0.4755 - val_loss: 2.1761
# Epoch 3/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7365 - loss: 0.7238 - val_accuracy: 0.4730 - val_loss: 2.2240
# Epoch 4/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7333 - loss: 0.7352 - val_accuracy: 0.4684 - val_loss: 2.2348
# Epoch 5/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7342 - loss: 0.7358 - val_accuracy: 0.4726 - val_loss: 2.2184
# Epoch 6/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7371 - loss: 0.7313 - val_accuracy: 0.4705 - val_loss: 2.1960
# Epoch 7/120
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7380 - loss: 0.7219 - val_accuracy: 0.4778 - val_loss: 2.1576
# Epoch 8/120
# ...

# %% [markdown]
# # Accuracy Graph Plotting

# %%
plt.subplot(1,2,1)
plt.plot(r.history['accuracy'], label=' training accuracy')
plt.plot(r.history['val_accuracy'], label=' validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Prediction

# %%
predict=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
n=10
class_names=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
for i in range(n):
  plt.subplot(2,5,i+1)
  plt.imshow(x_test[i])
  predicted_labels=np.argmax(predict[i])
  true_labels=y_test[i][0]
  plt.title(f' predicted:{class_names[predicted_labels]} \n true: {class_names[true_labels]}')
  plt.tight_layout()
  plt.show()
